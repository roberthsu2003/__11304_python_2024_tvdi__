# %%
l1:list = [2, 4, 6, 8, 10]
#查元素的數量
print(len(l1))

#那一個class建立的實體(資料類型)
print(type(l1))
# Out:
# 5
# <class 'list'>

# %%
#實體的方法method()
l1.append(12)
print(l1)
# Out:
# [2, 4, 6, 8, 10, 12]

# %%
l1.pop()
l1
# Out:
# [2, 4, 6, 8, 10]
