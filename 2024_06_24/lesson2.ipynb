# %%
import data
data.load_data()
# Out:
# [{'sna': '捷運科技大樓站',
#   'sarea': '大安區',
#   'mday': '2024-06-24 13:53:20',
#   'ar': '復興南路二段235號前',
#   'act': '1',
#   'updateTime': '2024-06-24 13:55:52',
#   'total': 28,
#   'rent_bikes': 0,
#   'lat': 25.02605,
#   'lng': 121.5436,
#   'retuen_bikes': 28},
#  {'sna': '復興南路二段273號前',
#   'sarea': '大安區',
#   'mday': '2024-06-24 13:52:22',
#   'ar': '復興南路二段273號西側',
#   'act': '1',
#   'updateTime': '2024-06-24 13:55:52',
#   'total': 21,
#   'rent_bikes': 5,
#   'lat': 25.02565,
#   'lng': 121.54357,
#   'retuen_bikes': 16},
#  {'sna': '國北教大實小東側門',
#   'sarea': '大安區',
#   'mday': '2024-06-24 13:54:22',
#   'ar': '和平東路二段96巷7號',
#   'act': '1',
#   'updateTime': '2024-06-24 13:55:52',
#   'total': 16,
#   'rent_bikes': 16,
#   'lat': 25.02429,
#   'lng': 121.54124,
#   'retuen_bikes': 0},
#  {'sna': '和平公園東側',
#   'sarea': '大安區',
#   'mday': '2024-06-24 13:54:22',
#   'ar': '和平東路二段118巷33號',
#   'act': '1',
#   'updateTime': '2024-06-24 13:55:52',
#   'total': 11,
#   'rent_bikes': 9,
# ...
