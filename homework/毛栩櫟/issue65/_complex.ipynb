# %%
students:list[list] = [
                        ['Amy',99,70,50],
                        ['Debby',80,65,100],
                        ['Jenny',70,98,85]
                    ]
print(students)
# Out:
# [['Amy', 99, 70, 50], ['Debby', 80, 65, 100], ['Jenny', 70, 98, 85]]

# %%
students:list[dict]= [
    {'name':'Leon','chinese':78,'english':92,'math':65},
    {'name':'Eric','chinese':80,'english':59,'math':88},
    {'name':'Alan','chinese':77,'english':100,'math':64},
]
students
# Out:
# [{'name': 'Leon', 'chinese': 78, 'english': 92, 'math': 65},
#  {'name': 'Eric', 'chinese': 80, 'english': 59, 'math': 88},
#  {'name': 'Alan', 'chinese': 77, 'english': 100, 'math': 64}]
