# %%
students:list[list] = [
                        ['anna',88,92,85],
                        ['robert',78,92,65],
                        ['alice',85,72,95]
                    ]

students
# Out:
# [['clare', 88, 92, 85], ['robert', 78, 92, 65], ['alice', 85, 72, 95]]

# %%
students:list[dict] = [
   {'name':'anna','chinese':88,'english':92,'math':85},
   {'name':'robert','chinese':88,'english':92,'math':85},
   {'name':'alice','chinese':88,'english':92,'math':85}
]

students
# Out:
# [{'name': 'anna', 'chinese': 88, 'english': 92, 'math': 85},
#  {'name': 'robert', 'chinese': 88, 'english': 92, 'math': 85},
#  {'name': 'alice', 'chinese': 88, 'english': 92, 'math': 85}]
