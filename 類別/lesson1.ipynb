# %%
print("Hello! Python!")
# Out:
# Hello! Python!

# %%
n = 10
m = 20
print(n+m)
# Out:
# 30

# %%
n = 10
type(n)
# Out:
# int

# %%
class Student():
    pass

s1 = Student()
type(s1)
# Out:
# __main__.Student
